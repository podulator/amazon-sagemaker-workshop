# %%
import boto3, os
import pandas as pd
import json
os.environ['AWS_DEFAULT_REGION']="us-east-1"
client = boto3.client('lex-models')

# %% [markdown]
# ## Prepare slot values from dataset

# %%
movies = pd.read_csv('./movies.csv',  names=['ITEM_ID','title','genre'], engine= 'python', header = 0)
movies.head()
# Out:
#    ITEM_ID                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                          genre
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
import re

def split_it(title):
    p = re.compile('(.*)(\(\d\d\d\d\))')
    if p.search(title):
        return p.search(title).group(1)
    else: 
        return title

titles =movies['title'].apply(split_it).unique()

# %%
slot_value_list = []

for val in titles[:3000].tolist():
    data = {}
    data['value'] = val
    slot_value_list.append(data)

# %% [markdown]
# ## Create slot type for watched movies

# %%
#checksum = client.get_slot_type(name='watchedMovie', version='$LATEST')['checksum']
response = client.put_slot_type(
    name='watchedMovie',
    description='A movie which the user has already watched',
    valueSelectionStrategy='ORIGINAL_VALUE',
    enumerationValues=slot_value_list,
    createVersion=False
)

# %% [markdown]
# ## Create movie recommendation intent

# %%
response = client.put_intent(
    name='MovieRecommenderIntent',
    description='This intent allows to get movie recommendations',
    slots=[
        {
            'name': 'watchedMovie',
            'description': 'A movie that the user already watched',
            'slotConstraint': 'Required',
            'slotType': 'watchedMovie',
            'slotTypeVersion': '$LATEST',
            'valueElicitationPrompt': {
                'messages': [
                    {
                        'contentType': 'PlainText',
                        'content': 'To make a good recommendation. Tell me a movie which you really liked!'
                    },
                ],
                'maxAttempts': 3
            },
            'priority': 1
        },
    ],
    sampleUtterances=[
        'Can you recommend me a movie','Can you recommend me a movie that is similar to {watchedMovie}', 'Which movie should i watch', 'Which movie should i see', 'What is a great movie', "Tell me a great movie similar to {watchedMovie}"
    ],
    confirmationPrompt={
        'messages': [
            {
                'contentType': 'PlainText',
                'content': 'Do you want a movie similar to {watchedMovie}'

            }
        ],
        'maxAttempts': 1
    },
    rejectionStatement={
        'messages': [
            {
                'contentType': 'PlainText',
                'content': 'Okay, not recommending you a movie!'

            },
        ],
        'responseCard': 'string'
    },
    fulfillmentActivity={
        'type': 'CodeHook',
        'codeHook': {
            'messageVersion' : '1.0',
            'uri': 'arn:aws:lambda:us-east-1:028626156119:function:movie-chatbot-movieChatbotFunction-SOCS3XYBBQGH'
        }
    },
        createVersion=False
)

# %% [markdown]
# ## Create the chatbot

# %%
response = client.put_bot(
    name='MovieRecommendationBot',
    description='This bot provides movie recommendations based movies you have seen',
    intents=[
        {
            'intentName': 'MovieRecommenderIntent',
            'intentVersion': '$LATEST'
        },
    ],
    clarificationPrompt={
        'messages': [
            {
                'contentType': 'PlainText',
                'content': 'Hi. If you want a movie recommendation, ask What is a great movie?'
                
            },
        ],
        'maxAttempts': 3
    },
    abortStatement={
        'messages': [
            {
                'contentType': 'PlainText',
                'content': 'Thanks for using the movie recommender bot. Goodbye!'
                
            },
        ]
    },
    idleSessionTTLInSeconds=120,
    voiceId='Joanna',
    processBehavior='BUILD',
    locale='en-US',
    childDirected=False,
    createVersion=False
)

# %% [markdown]
# ## Delete resources

# %%
response = client.delete_bot(
    name='MovieRecommendationBot'
)

# %%
response = client.delete_intent(
    name='MovieRecommenderIntent'
)

# %%
response = client.delete_slot_type(
    name='watchedMovie'
)

# %% [markdown]
# ## Personalize test

# %%
client = boto3.client('personalize-runtime')
s3 = boto3.client('s3')

# %%
movieName = "Silence of the lambs"

# %%
s3.download_file('movie-chatbot-deployment', 'movies.dat', '/tmp/movies.dat')
movies = pd.read_csv('/tmp/movies.dat', sep='::', names=['ITEM_ID','title','genre'], engine= 'python')

def getIDForMovieName(movieName):
    filteredMovies = movies[movies['title'].str.contains(movieName, case=False)]
    if (len(filteredMovies.index) > 0 ):
        print(filteredMovies)
        return filteredMovies.iloc[0][0]
    return None

# %%
itemId = getIDForMovieName(movieName)
# Out:
#      ITEM_ID                             title           genre
# 589      593  Silence of the Lambs, The (1991)  Drama|Thriller

# %%
rec_response = client.get_recommendations(
    campaignArn='arn:aws:personalize:us-east-1:028626156119:campaign/DEMO-sims-campaign-42079',
    itemId=str(itemId),
    numResults=10
)
rec_items = [int(x['itemId']) for x in rec_response['itemList']]
movies.loc[rec_items[:5]].values.tolist()
# Out:
# [[1379, 'Young Guns II (1990)', 'Action|Comedy|Western'],
#  [321, 'Strawberry and Chocolate (Fresa y chocolate) (1993)', 'Drama'],
#  [1232, 'Stalker (1979)', 'Mystery|Sci-Fi'],
#  [612, 'Pallbearer, The (1996)', 'Comedy'],
#  [1105, 'Children of the Corn IV: The Gathering (1996)', 'Horror']]

# %%
rec_response = client.get_recommendations(
    campaignArn='arn:aws:personalize:us-east-1:028626156119:campaign/DEMO-sims-hpo-campaign-42079',
    itemId=str(itemId),
    numResults=10
)
rec_items = [int(x['itemId']) for x in rec_response['itemList']]
movies.loc[rec_items[:10]]
# Out:
#       ITEM_ID                                              title  \
# 318       321  Strawberry and Chocolate (Fresa y chocolate) (...
# 1358     1379                               Young Guns II (1990)
# 1213     1232                                     Stalker (1979)
# 608       612                             Pallbearer, The (1996)
# 50         51                              Guardian Angel (1994)
# 296       299                                      Priest (1994)
# 1089     1105      Children of the Corn IV: The Gathering (1996)
# 1704     1757                              Duoluo tianshi (1995)
# 16         17                       Sense and Sensibility (1995)
# 36         37                      Across the Sea of Time (1995)
#
#                       genre
# 318                   Drama
# 1358  Action|Comedy|Western
# 1213         Mystery|Sci-Fi
# 608                  Comedy
# 50    Action|Drama|Thriller
# 296                   Drama
# 1089                 Horror
# 1704                  Drama
# 16            Drama|Romance
# 36              Documentary

# %%
movies.loc[40:100]
# Out:
#      ITEM_ID                                              title  \
# 40        42                             Dead Presidents (1995)
# 41        43                                 Restoration (1995)
# 42        44                               Mortal Kombat (1995)
# 43        45                                  To Die For (1995)
# 44        46               How to Make an American Quilt (1995)
# 45        47                        Seven (a.k.a. Se7en) (1995)
# 46        48                                  Pocahontas (1995)
# 47        49                       When Night Is Falling (1995)
# 48        50                         Usual Suspects, The (1995)
# 49        52                            Mighty Aphrodite (1995)
# 50        53                                    Lamerica (1994)
# 51        54                              Big Green, The (1995)
# 52        55                                     Georgia (1995)
# 53        56                     Kids of the Round Table (1995)
# 54        57                       Home for the Holidays (1995)
# 55        58                  Postman, The (Postino, Il) (1994)
# 56        59       Confessional, The (Confessionnal, Le) (1995)
# 57        60                 Indian in the Cupboard, The (1995)
# 58        61                              Eye for an Eye (1996)
# 59        62                          Mr. Holland's Opus (1995)
# 60        63  Don't Be a Menace to South Central While Drink...
# 61        64                               Two if by Sea (1996)
# 62        65                                    Bio-Dome (1996)
# 63        66          Lawnmower Man 2: Beyond Cyberspace (1996)
# 64        67                                    Two Bits (1995)
# 65        68                 French Twist (Gazon maudit) (1995)
# 66        69                                      Friday (1995)
# 67        70                         From Dusk Till Dawn (1996)
# 68        71                                   Fair Game (1995)
# 69        72                       Kicking and Screaming (1995)
# ..       ...                                                ...
# 71        74                                Bed of Roses (1996)
# 72        75                                   Big Bully (1996)
# 73        76                                   Screamers (1995)
# 74        77                                   Nico Icon (1995)
# 75        78                         Crossing Guard, The (1995)
# 76        79                                  Juror, The (1996)
# 77        80        White Balloon, The (Badkonake sefid) (1995)
# 78        81     Things to Do in Denver When You're Dead (1995)
# 79        82                    Antonia's Line (Antonia) (1995)
# 80        83    Once Upon a Time... When We Were Colored (1995)
# 81        84                 Last Summer in the Hamptons (1995)
# 82        85                          Angels and Insects (1995)
# 83        86                                White Squall (1996)
# 84        87                           Dunston Checks In (1996)
# 85        88                                 Black Sheep (1996)
# 86        89                                Nick of Time (1995)
# 87        90                 Journey of August King, The (1995)
# 88        92                                 Mary Reilly (1996)
# 89        93                         Vampire in Brooklyn (1995)
# 90        94                             Beautiful Girls (1996)
# 91        95                                Broken Arrow (1996)
# 92        96                      In the Bleak Midwinter (1995)
# 93        97                            Hate (Haine, La) (1995)
# 94        98                                    Shopping (1994)
# 95        99               Heidi Fleiss: Hollywood Madam (1995)
# 96       100                                   City Hall (1996)
# 97       101                               Bottle Rocket (1996)
# 98       102                                   Mr. Wrong (1996)
# 99       103                               Unforgettable (1996)
# 100      104                               Happy Gilmore (1996)
#
#                                         genre
# 40                         Action|Crime|Drama
# 41                                      Drama
# 42                   Action|Adventure|Fantasy
# 43                      Comedy|Drama|Thriller
# 44                              Drama|Romance
# 45                           Mystery|Thriller
# 46   Animation|Children|Drama|Musical|Romance
# 47                              Drama|Romance
# 48                     Crime|Mystery|Thriller
# 49                       Comedy|Drama|Romance
# 50                            Adventure|Drama
# 51                            Children|Comedy
# 52                                      Drama
# 53                 Adventure|Children|Fantasy
# 54                                      Drama
# 55                       Comedy|Drama|Romance
# 56                              Drama|Mystery
# 57                 Adventure|Children|Fantasy
# 58                             Drama|Thriller
# 59                                      Drama
# 60                               Comedy|Crime
# 61                             Comedy|Romance
# 62                                     Comedy
# 63                     Action|Sci-Fi|Thriller
# 64                                      Drama
# 65                             Comedy|Romance
# 66                                     Comedy
# 67              Action|Comedy|Horror|Thriller
# 68                                     Action
# 69                               Comedy|Drama
# ..                                        ...
# 71                              Drama|Romance
# 72                               Comedy|Drama
# 73                     Action|Sci-Fi|Thriller
# 74                                Documentary
# 75                Action|Crime|Drama|Thriller
# 76                             Drama|Thriller
# 77                             Children|Drama
# 78                        Crime|Drama|Romance
# 79                               Comedy|Drama
# 80                              Drama|Romance
# 81                               Comedy|Drama
# 82                              Drama|Romance
# 83                     Action|Adventure|Drama
# 84                            Children|Comedy
# 85                                     Comedy
# 86                            Action|Thriller
# 87                                      Drama
# 88                      Drama|Horror|Thriller
# 89                      Comedy|Horror|Romance
# 90                       Comedy|Drama|Romance
# 91                  Action|Adventure|Thriller
# 92                               Comedy|Drama
# 93                                Crime|Drama
# 94                            Action|Thriller
# 95                                Documentary
# 96                             Drama|Thriller
# 97             Adventure|Comedy|Crime|Romance
# 98                                     Comedy
# 99                    Mystery|Sci-Fi|Thriller
# 100                                    Comedy
#
# [61 rows x 3 columns]

# %%
# Read in CSV file and create simple lookup dictionary, we could use pandas, however this pulls in a huge dependency and we want to keep it simple
moviesDict = {}
movies = csv.DictReader(open("movies.csv"))
for row in movies:
    moviesDict.update({row['ITEM_ID'] : {'id': row['ITEM_ID'], 'title': row['title'], 'genre': row['genre']}})
moviesDict['1']
# Out:
# {'id': '1',
#  'title': 'Toy Story (1995)',
#  'genre': 'Adventure|Animation|Children|Comedy|Fantasy'}

# %%
def searchItemByTitle(movies, title):
    for k in movies:
        if title.lower() in movies[k]['title'].lower():
            return movies[k]
    return None

# %%
movieName = 'jum'
searchItemByTitle(moviesDict, movieName)
# Out:
# {'id': '2', 'title': 'Jumanji (1995)', 'genre': 'Adventure|Children|Fantasy'}
